# %%
# HRNet Alzheimer's Disease Classification - Google Colab Notebook

This notebook will guide you through training and testing the HRNet model on your Alzheimer's dataset using the codebase you provided.

---

## 1. Setup Google Drive and Clone Repository

```python
from google.colab import drive
drive.mount('/content/drive')

# Change this path to your Google Drive location where you upload your project folder
PROJECT_PATH = '/content/drive/MyDrive/HRNet-Facial-Landmark-Detection'

# !cp -r "$PROJECT_PATH" /content/
# %cd /content/HRNet-Facial-Landmark-Detection
```

---

## 2. Install Dependencies

```python
# !pip install torch==1.10.0 torchvision==0.11.1
# !pip install -r requirements.txt
```

---

## 3. Prepare Data

- Ensure your `train/` and `test/` folders are inside the project directory in Google Drive before running this notebook.
- The folder structure should be:
  - `train/MildDemented/`, `train/ModerateDemented/`, etc.
  - `test/MildDemented/`, `test/ModerateDemented/`, etc.

---

## 4. Train the HRNet Model

```python
# !python tools/train.py --cfg experiments/alzheimer/face_alignment_ad_hrnet_w18.yaml
```

---

## 5. Test/Evaluate the Model

```python
# !python tools/test.py --cfg experiments/alzheimer/face_alignment_ad_hrnet_w18.yaml --model-file checkpoints/hrnet_w18_landmark.pth
```

---

## 6. (Optional) View Results

- Check the `output/Alzheimer/face_alignment_ad_hrnet_w18/` and `log/Alzheimer/hrnet/` folders for results and logs.

---

## Notes
- If you modify the dataset location or configuration, update the YAML file in `experiments/alzheimer/` accordingly.
- For custom evaluation or visualization, you can add new code cells as needed.
